# %%
# %pylab inline
import pandas as pd
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import warnings
from itertools import product
# Out:
# Populating the interactive namespace from numpy and matplotlib
# D:\Users\oleji\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['product']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Pасчетное потребление энергии в мегаваттах (МВт) в часах

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv', index_col=['Datetime'], parse_dates=['Datetime'], dayfirst=True)

# %%
df.head(10)
# Out:
#                      DUQ_MW
# Datetime
# 2005-12-31 01:00:00  1458.0
# 2005-12-31 02:00:00  1377.0
# 2005-12-31 03:00:00  1351.0
# 2005-12-31 04:00:00  1336.0
# 2005-12-31 05:00:00  1356.0
# 2005-12-31 06:00:00  1372.0
# 2005-12-31 07:00:00  1402.0
# 2005-12-31 08:00:00  1425.0
# 2005-12-31 09:00:00  1502.0
# 2005-12-31 10:00:00  1556.0

# %% [markdown]
# Стабилизация дисперсии

# %%
plt.figure(figsize(15,7))
df.plot()
plt.ylabel('DUQ')
pylab.show()

# %%
df['DUQ_box'], lmbda = stats.boxcox(df.DUQ_MW)
plt.figure(figsize(15,7))
df.DUQ_box.plot()
plt.ylabel(u'Transformed DUQ_MW')
print("Оптимальный параметр преобразования Кокса- Бокса: %f" % lmbda)
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df.DUQ_box)[1])
# Out:
# Оптимальный параметр преобразования Кокса- Бокса: -0.598402
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# Стационарность

# %%
df['DUQ_box_diff'] = df.DUQ_box - df.DUQ_box.shift(12)
plt.figure(figsize(15,10))
sm.tsa.seasonal_decompose(df['DUQ_box_diff'][12:],freq=4).plot()
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df.DUQ_box_diff[12:])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# ### Преобразование по дням

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('D', on = 'date').sum()
df
# Out:
#              DUQ_MW
# date
# 2005-01-01  31111.0
# 2005-01-02  32958.0
# 2005-01-03  37991.0
# 2005-01-04  38658.0
# 2005-01-05  41064.0
# ...             ...
# 2018-07-30  40457.0
# 2018-07-31  41635.0
# 2018-08-01  41793.0
# 2018-08-02  41667.0
# 2018-08-03   1656.0
#
# [4963 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('DUQ')
pylab.show()
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# ### Преобразование по неделям

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('W', on = 'date').sum()
df
# Out:
#               DUQ_MW
# date
# 2005-01-02   64069.0
# 2005-01-09  273052.0
# 2005-01-16  274529.0
# 2005-01-23  301980.0
# 2005-01-30  297042.0
# ...              ...
# 2018-07-08  323737.0
# 2018-07-15  322957.0
# 2018-07-22  307617.0
# 2018-07-29  301925.0
# 2018-08-05  167208.0
#
# [710 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('DUQ')
pylab.show()
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.000000

# %% [markdown]
# ### Преобразование по месяцам

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])

# %%
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %% [markdown]
# ###  Преобразование по месяцам

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('M', on = 'date').sum()
df
# Out:
#                DUQ_MW
# date
# 2005-01-31  1252603.0
# 2005-02-28  1113277.0
# 2005-03-31  1215163.0
# 2005-04-30  1037920.0
# 2005-05-31  1106793.0
# ...               ...
# 2018-04-30  1008305.0
# 2018-05-31  1166120.0
# 2018-06-30  1203606.0
# 2018-07-31  1387774.0
# 2018-08-31    85116.0
#
# [164 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('DUQ')
pylab.show()
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.989844

# %% [markdown]
# ### Преобразование по годам

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('Y', on = 'date').sum()
df
# Out:
#                 DUQ_MW
# date
# 2005-12-31  14830490.0
# 2006-12-31  14562752.0
# 2007-12-31  15003675.0
# 2008-12-31  14699758.0
# 2009-12-31  13964771.0
# 2010-12-31  14959342.0
# 2011-12-31  14925032.0
# 2012-12-31  15097835.0
# 2013-12-31  14822887.0
# 2014-12-31  14567085.0
# 2015-12-31  14313055.0
# 2016-12-31  14025081.0
# 2017-12-31  13510127.0
# 2018-12-31   8230525.0

# %%
plt.figure(figsize(15,7))
df['DUQ_MW'].plot()
plt.ylabel('DUQ')
pylab.show()
print(" Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(df['DUQ_MW'])[1])
# Out:
#  Критерий Дики-Фуллера: p=0.998716

# %% [markdown]
# Графики относительно часов, дней и недель больше походят на стационарные, критерий дики-фуллера также отвергает гипотезу о нестационарности.
#
# Графики относительно месяцев выглядят хорошо для определения на глаз, не виден тренд, график выглядит стационарным, но критерий этого не подтверждает, нужно выполнить методы по уменьшению разброса и улучшению критерия Дики-Фуллера.
#
# Графики относительно годов не выглядит стационарным, виден убывающий тренд, критерий подтверждает на цифрах визуальные данные Исходя из иследований, преобразование по дням, неделям и часам стационары, критерий Дики-Фуллера это подтверждает.Преобразование по месяцам стационарен (похож), критерий отвергает это предположение,нужны преобразования.Года не стационары

# %% [markdown]
# # Регрессия временного ряда

# %%
df = pd.read_csv(r'C:/Users/oleji/Desktop/dta/dz3/DUQ_hourly.csv')
df["Datetime"] = pd.to_datetime(df["Datetime"])
df['date'] = df["Datetime"].apply( lambda df : 
datetime.datetime(year=df.year, month=df.month, day=df.day))
df.set_index(df["date"],inplace=True)
df
# Out:
#                       Datetime  DUQ_MW       date
# date
# 2005-12-31 2005-12-31 01:00:00  1458.0 2005-12-31
# 2005-12-31 2005-12-31 02:00:00  1377.0 2005-12-31
# 2005-12-31 2005-12-31 03:00:00  1351.0 2005-12-31
# 2005-12-31 2005-12-31 04:00:00  1336.0 2005-12-31
# 2005-12-31 2005-12-31 05:00:00  1356.0 2005-12-31
# ...                        ...     ...        ...
# 2018-01-01 2018-01-01 20:00:00  1962.0 2018-01-01
# 2018-01-01 2018-01-01 21:00:00  1940.0 2018-01-01
# 2018-01-01 2018-01-01 22:00:00  1891.0 2018-01-01
# 2018-01-01 2018-01-01 23:00:00  1820.0 2018-01-01
# 2018-01-02 2018-01-02 00:00:00  1721.0 2018-01-02
#
# [119068 rows x 3 columns]

# %%
df = df.resample('W', on = 'date').sum()
df
# Out:
#               DUQ_MW
# date
# 2005-01-02   64069.0
# 2005-01-09  273052.0
# 2005-01-16  274529.0
# 2005-01-23  301980.0
# 2005-01-30  297042.0
# ...              ...
# 2018-07-08  323737.0
# 2018-07-15  322957.0
# 2018-07-22  307617.0
# 2018-07-29  301925.0
# 2018-08-05  167208.0
#
# [710 rows x 1 columns]

# %%
plt.figure(figsize(15,7))
data['DUQ_MW'].plot()
plt.ylabel('DUQ')
pylab.show()

# %% [markdown]
# # Обучение временного ряда

# %%
plt.figure(figsize(15,8))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df['DUQ_MW'][13:].values.squeeze(), lags=48, ax=ax)
pylab.show()
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df['DUQ_MW'][13:].values.squeeze(), lags=48, ax=ax)
pylab.show()

# %%
#номер последнего значимого сезонного лага Q = 4
Qs = range(0, 5)
#номер не сезонного значимого лага q = 11
qs = range(0, 12)
#номер последнего значимого сезонного лага P = 4
Ps = range(0, 5)
#номер не сезонного значимого лага p = 10
ps = range(0, 11)
D = 1
d = 1

# %%
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 3300
